# %%
#imports

from FinanceDataManager import FinanceDataManager
from Preprocessing import  Preprocessing
from LSTM_Network import LSTM_Network

# %%
finance_data_manager = FinanceDataManager("AAPL", start = "2003-01-01", end = "2017-01-01")
prices = finance_data_manager.get_prices()

prep = Preprocessing("stock_prices.csv", 0.9)
prep.gen_train(10)
prep.gen_test(10)

X_train = prep.X_train.reshape((3379, 10, 1)) / 200
Y_train = prep.Y_train / 200

X_test = prep.X_test.reshape(359, 10, 1) / 200
Y_test = prep.Y_test / 200

LSTM = LSTM_Network(X_train, X_test , Y_train, Y_test)
LSTM.train()
LSTM.evaluate()
# Out:
# Train on 3379 samples
# Epoch 1/50
# 3379/3379 [==============================] - 5s 2ms/sample - loss: 0.0056
# Epoch 2/50
# 3379/3379 [==============================] - 1s 364us/sample - loss: 1.2542e-04
# Epoch 3/50
# 3379/3379 [==============================] - 1s 377us/sample - loss: 1.0536e-04
# Epoch 4/50
# 3379/3379 [==============================] - 1s 377us/sample - loss: 1.0208e-04
# Epoch 5/50
# 3379/3379 [==============================] - 1s 383us/sample - loss: 1.0045e-04
# Epoch 6/50
# 3379/3379 [==============================] - 1s 382us/sample - loss: 1.0177e-04
# Epoch 7/50
# 3379/3379 [==============================] - 1s 381us/sample - loss: 9.9707e-05
# Epoch 8/50
# 3379/3379 [==============================] - 1s 386us/sample - loss: 1.0110e-04
# Epoch 9/50
# 3379/3379 [==============================] - 1s 411us/sample - loss: 1.0463e-04
# Epoch 10/50
# 3379/3379 [==============================] - 1s 396us/sample - loss: 9.6887e-05
# Epoch 11/50
# 3379/3379 [==============================] - 1s 431us/sample - loss: 1.0466e-04
# Epoch 12/50
# 3379/3379 [==============================] - 1s 395us/sample - loss: 1.0061e-04
# Epoch 13/50
# 3379/3379 [==============================] - 1s 378us/sample - loss: 1.0213e-04
# Epoch 14/50
# 3379/3379 [==============================] - 1s 389us/sample - loss: 9.9334e-05
# Epoch 15/50
# 3379/3379 [==============================] - 1s 367us/sample - loss: 9.9886e-05
# Epoch 16/50
# 3379/3379 [==============================] - 1s 362us/sample - loss: 9.3324e-05
# Epoch 17/50
# 3379/3379 [==============================] - 1s 366us/sample - loss: 9.5115e-05
# Epoch 18/50
# 3379/3379 [==============================] - 1s 396us/sample - loss: 9.7387e-05
# Epoch 19/50
# 3379/3379 [==============================] - 1s 410us/sample - loss: 8.8659e-05
# Epoch 20/50
# 3379/3379 [==============================] - 1s 393us/sample - loss: 9.8515e-05
# Epoch 21/50
# 3379/3379 [==============================] - 1s 412us/sample - loss: 1.0123e-04
# Epoch 22/50
# 3379/3379 [==============================] - 1s 385us/sample - loss: 9.9956e-05
# Epoch 23/50
# 3379/3379 [==============================] - 1s 369us/sample - loss: 9.0840e-05
# Epoch 24/50
# 3379/3379 [==============================] - 1s 369us/sample - loss: 8.8050e-05
# Epoch 25/50
# 3379/3379 [==============================] - 1s 374us/sample - loss: 9.5094e-05
# Epoch 26/50
# 3379/3379 [==============================] - 1s 368us/sample - loss: 9.3217e-05
# Epoch 27/50
# 3379/3379 [==============================] - 1s 387us/sample - loss: 9.0429e-05
# Epoch 28/50
# 3379/3379 [==============================] - 1s 386us/sample - loss: 8.7555e-05
# Epoch 29/50
# 3379/3379 [==============================] - 1s 370us/sample - loss: 8.6482e-05
# Epoch 30/50
# 3379/3379 [==============================] - 1s 372us/sample - loss: 8.4484e-05
# Epoch 31/50
# 3379/3379 [==============================] - 1s 380us/sample - loss: 8.6740e-05
# Epoch 32/50
# 3379/3379 [==============================] - 1s 378us/sample - loss: 8.3691e-05
# Epoch 33/50
# 3379/3379 [==============================] - 1s 395us/sample - loss: 9.0492e-05
# Epoch 34/50
# 3379/3379 [==============================] - 1s 408us/sample - loss: 8.1975e-05
# Epoch 35/50
# 3379/3379 [==============================] - 1s 385us/sample - loss: 8.2423e-05
# Epoch 36/50
# 3379/3379 [==============================] - 1s 370us/sample - loss: 7.4951e-05
# Epoch 37/50
# 3379/3379 [==============================] - 1s 373us/sample - loss: 8.1280e-05
# Epoch 38/50
# 3379/3379 [==============================] - 1s 384us/sample - loss: 8.4433e-05
# Epoch 39/50
# 3379/3379 [==============================] - 1s 374us/sample - loss: 7.7552e-05
# Epoch 40/50
# 3379/3379 [==============================] - 1s 370us/sample - loss: 7.2173e-05
# Epoch 41/50
# 3379/3379 [==============================] - 1s 378us/sample - loss: 7.7688e-05
# Epoch 42/50
# 3379/3379 [==============================] - 1s 375us/sample - loss: 7.3598e-05
# Epoch 43/50
# 3379/3379 [==============================] - 1s 369us/sample - loss: 7.4333e-05
# Epoch 44/50
# 3379/3379 [==============================] - 1s 385us/sample - loss: 7.2640e-05
# Epoch 45/50
# 3379/3379 [==============================] - 1s 388us/sample - loss: 7.4308e-05
# Epoch 46/50
# 3379/3379 [==============================] - 1s 390us/sample - loss: 7.1153e-05
# Epoch 47/50
# 3379/3379 [==============================] - 1s 383us/sample - loss: 6.7638e-05
# Epoch 48/50
# 3379/3379 [==============================] - 1s 375us/sample - loss: 6.3901e-05
# Epoch 49/50
# 3379/3379 [==============================] - 1s 382us/sample - loss: 6.3569e-05
# Epoch 50/50
# 3379/3379 [==============================] - 1s 377us/sample - loss: 6.7246e-05
# 359/1 [========================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...
# 0.0002109471586608123
# [[232.39224]]

# %%
LSTM.model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 10, 20)            1760
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 20)                3280
# _________________________________________________________________
# dense (Dense)                (None, 1)                 21
# =================================================================
# Total params: 5,061
# Trainable params: 5,061
# Non-trainable params: 0
# _________________________________________________________________
